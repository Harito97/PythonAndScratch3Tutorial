# %%
# a = 'Hai'

def func1():
    global a
    a = 'Phuong'

func1()

print(a)
# Out:
# Phuong

# %%
number1 = 0
number2 = 3

def cal():
    global number2
    number1 = 2
    # number2 = 1
    return number1 + number2

print(cal())
# Out:
# 5

# %% [markdown]
# Homework 22/04/2024

# %%
for i in range(3000): print('I love you 3000!')
# Out:
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# ...

# %%
print('I love you 3000!\n' * 3000)
# Out:
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# I love you 3000!
# ...

# %% [markdown]
# Homework
# Tính giai thừa:
# 4! = 4*3*2*1
# 1! = 0! = 1
# (-9)! = None
