# %%
# %pip install requests --quiet --upgrade
import requests
# Out:
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import requests
law_url = 'https://vbpl.vn/botuphap/Pages/vbpq-toanvan.aspx?ItemID=25699'
response = requests.get(law_url)  
print(response)
page_contents = response.text
with open("clean_law_data.txt", 'w') as f: 
    f.write(page_contents)

# %%
law_url = 'https://vbpl.vn/botuphap/Pages/vbpq-toanvan.aspx?ItemID=25699'
response = requests.get(law_url)      #requests.get()'

# %%
print(response)
# Out:
# <Response [200]>

# %%
response.status_code    #Here we are checking the Status code, -> 200-299 will mean that the request was successful
# Out:
# 200

# %%
page_contents = response.text
len(page_contents)    #The `len` fucnction tells us the length of the response object
# Out:
# 102759

# %%
page_contents[:500]   #This displays the first 500 characters of `page_contents`
# Out:
# '<!--Timer:00:00:00.0037444==UrlControls:\\VBQPPL_UserControls\\Publishing_22\\uc_ToanVan.ascx.wpLoadUserControls_EnVi -->\r\n<!--Timer:00:00:00.0019217==UrlControls:\\VBQPPL_UserControls\\Publishing_22\\uc_menuNambanhanh.ascx.wpLoadUserControls_EnVi -->\r\n<!--Timer:00:00:00.0000027==UrlControls:\\VBQPPL_UserControls\\Publishing_22\\uc_MenuToanVan.ascx.wpLoadUserControls_EnVi -->\r\n\r\n<!DOCTYPE html >\n<html lang="en" class="sb-init ms-isBot" dir="ltr">\r\n    <head><meta http-equiv="X-UA-Compatible" content="IE='

# %%
with open("clean_law_data.txt", 'w') as f:  #Writing the html page to a file locally, i.e. a replica of real html page
    f.write(page_contents)

# %%
with open("clean_law_data.txt", "r", encoding="utf-8") as file:
    content = file.read()[2:]
    print(content)
# Out:
# trong>LUẬT</strong><br>
# <strong>Nuôi con nuôi</strong></p>
# <p align="center">
#     <strong>________</strong>
# </p>
# <p>
#     <em>Căn cứ Hiến pháp nước Cộng hòa xã hội chủ nghĩa Việt Nam năm 1992 đã được sửa đổi, bổ sung một số điều theo Nghị
#         quyết số <a target="_blank" class='toanvan'
#             href='/botuphap/pages/vbpq-timkiem.aspx?type=0&s=1&Keyword=51/2001/QH10&SearchIn=Title,Title1&IsRec=1&pv=0'>51/2001/QH10;</em><br></a>
#     <em>Quốc hội ban hành Luật Nuôi con nuôi.</em>
# </p>
# <p style="text-align&#58;center;">
#     <strong>Chương <a name="Chuong_I"></a>I</strong>
# </p>
# <p align="center">
#     <strong>NHỮNG QUY ĐỊNH CHUNG</strong>
# </p>
# <p>
#     <strong>Điều <a name="Chuong_I_Dieu_1"></a>1. Phạm vi điều chỉnh </strong>
# </p>
# <p>
#     Luật này quy định nguyên tắc, điều kiện nuôi con nuôi; thẩm quyền, trình tự, thủ tục giải quyết việc nuôi con nuôi;
# ...
